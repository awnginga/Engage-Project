# %% [markdown]
# <a href="https://colab.research.google.com/github/awnginga/Engage-Project/blob/main/practical_for_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_excel('/content/child_data .xlsx')
df
# Out:
#      Age (months)  Sex  Mother's education  Area  Wealth index quintile  \
# 0              45    0                   1     0                      0
# 1              45    1                   0     0                      1
# 2              36    1                   0     0                      2
# 3              51    0                   0     0                      2
# 4              56    0                   0     0                      2
# ..            ...  ...                 ...   ...                    ...
# 763             7    0                   0     1                      2
# 764             0    1                   1     1                      2
# 765            56    0                   0     1                      2
# 766            18    0                   0     1                      2
# 767             7    0                   0     1                      4
#
#      Child's weight (kilograms)
# 0                          16.2
# 1                          13.5
# ...

# %%
df.isnull()
# Out:
#      Age (months)    Sex  Mother's education   Area  Wealth index quintile  \
# 0           False  False               False  False                  False
# 1           False  False               False  False                  False
# 2           False  False               False  False                  False
# 3           False  False               False  False                  False
# 4           False  False               False  False                  False
# ..            ...    ...                 ...    ...                    ...
# 763         False  False               False  False                  False
# 764         False  False               False  False                  False
# 765         False  False               False  False                  False
# 766         False  False               False  False                  False
# 767         False  False               False  False                  False
#
#      Child's weight (kilograms)
# 0                         False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age (months)                768 non-null    int64
#  1   Sex                         768 non-null    int64
#  2   Mother's education          768 non-null    int64
#  3   Area                        768 non-null    int64
#  4   Wealth index quintile       768 non-null    int64
#  5   Child's weight (kilograms)  768 non-null    float64
# dtypes: float64(1), int64(5)
# memory usage: 36.1 KB

# %%
df.isnull().sum()
# Out:
# Age (months)                  0
# Sex                           0
# Mother's education            0
# Area                          0
# Wealth index quintile         0
# Child's weight (kilograms)    0
# dtype: int64

# %%
df.isnull().count()
# Out:
# Age (months)                  768
# Sex                           768
# Mother's education            768
# Area                          768
# Wealth index quintile         768
# Child's weight (kilograms)    768
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.title("Child Data")
sns.scatterplot(x="Age (months)",y="Child's weight (kilograms)",data=df)
plt.show()

# %%
x=df[["Age (months)"]]
y=df[["Child's weight (kilograms)"]]

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
model=linear_model.LinearRegression()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([[11.0719501 ],
#        [ 7.03991746],
#        [ 8.04792562],
#        [11.40795282],
#        [12.41596098],
#        [ 9.55993786],
#        [ 7.87992426],
#        [ 8.88793242],
#        [10.90394874],
#        [13.25596778],
#        [12.58396234],
#        [11.74395554],
#        [ 9.3919365 ],
#        [ 9.55993786],
#        [13.42396914],
#        [ 7.54392154],
#        [15.2719841 ],
#        [11.40795282],
#        [16.44799362],
#        [13.5919705 ],
#        [ 8.5519297 ],
#        [ 7.87992426],
#        [12.91996506],
#        [10.90394874],
#        [16.27999226],
#        [11.23995146],
#        [15.10398274],
#        [ 9.22393514],
#        [12.58396234],
#        [ 9.55993786],
#        [ 9.72793922],
#        [14.26397594],
#        [ 9.05593378],
#        [12.58396234],
#        [12.58396234],
#        [16.61599498],
#        [13.5919705 ],
#        [12.7519637 ],
#        [10.39994466],
#        [ 9.22393514],
#        [12.7519637 ],
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, label='Actual Values', color='blue', marker='.')

# Plot predicted values
plt.scatter(x_test, y_pred, label='Predicted Values', color='red', marker='.')

# Set labels and title
plt.xlabel('Age')
plt.ylabel('Weight')
plt.title('Actual vs Predicted Values')

# Add a legend
plt.legend()

# Show the plot
plt.show()
