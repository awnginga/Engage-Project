# %% [markdown]
# <a href="https://colab.research.google.com/github/awnginga/Engage-Project/blob/main/Engage_Practicals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic

# %%
#Load the dataset from the start (First ten)
df=pd.read_csv('/content/nhanes_reduced .csv')
df.head(10)
# Out:
#       ID SurveyYr  Gender  Age AgeDecade  AgeMonths       Education  \
# 0  51624  2009_10    male   34     30-39      409.0     High School
# 1  51625  2009_10    male    4       0-9       49.0             NaN
# 2  51630  2009_10  female   49     40-49      596.0    Some College
# 3  51638  2009_10    male    9       0-9      115.0             NaN
# 4  51646  2009_10    male    8       0-9      101.0             NaN
# 5  51647  2009_10  female   45     40-49      541.0    College Grad
# 6  51654  2009_10    male   66     60-69      795.0    Some College
# 7  51656  2009_10    male   58     50-59      707.0    College Grad
# 8  51657  2009_10    male   54     50-59      654.0  9 - 11th Grade
# 9  51659  2009_10  female   10    Oct-19      123.0             NaN
#
#   MaritalStatus     HHIncome  HHIncomeMid  ...  PhysActiveDays  TVHrsDay  \
# 0       Married  25000-34999      30000.0  ...             NaN       NaN
# ...

# %%
#Load the dataset from the bottom (last ten)
df.tail(10)
# Out:
#          ID SurveyYr  Gender  Age AgeDecade  AgeMonths       Education  \
# 6769  71879  2011_12    male   24     20-29        NaN    Some College
# 6770  71880  2011_12    male   46     40-49        NaN    Some College
# 6771  71882  2011_12  female   60     60-69        NaN  9 - 11th Grade
# 6772  71898  2011_12  female   65     60-69        NaN    Some College
# 6773  71907  2011_12    male   80       NaN        NaN     High School
# 6774  71908  2011_12  female   66     60-69        NaN    College Grad
# 6775  71909  2011_12    male   28     20-29        NaN  9 - 11th Grade
# 6776  71910  2011_12  female    0       0-9        5.0             NaN
# 6777  71911  2011_12    male   27     20-29        NaN    College Grad
# 6778  71915  2011_12    male   60     60-69        NaN    College Grad
#
#      MaritalStatus     HHIncome  HHIncomeMid  ...  PhysActiveDays   TVHrsDay  \
# 6769  NeverMarried    5000-9999       7500.0  ...             NaN  More_4_hr
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6779 entries, 0 to 6778
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               6779 non-null   int64
#  1   SurveyYr         6779 non-null   object
#  2   Gender           6779 non-null   object
#  3   Age              6779 non-null   int64
#  4   AgeDecade        6530 non-null   object
#  5   AgeMonths        3549 non-null   float64
#  6   Education        4645 non-null   object
#  7   MaritalStatus    4650 non-null   object
#  8   HHIncome         6194 non-null   object
#  9   HHIncomeMid      6194 non-null   float64
#  10  Poverty          6261 non-null   float64
#  11  HomeRooms        6731 non-null   float64
#  12  HomeOwn          6735 non-null   object
#  13  Work             5046 non-null   object
#  14  Weight           6724 non-null   float64
#  15  Height           6481 non-null   float64
# ...

# %%
df.shape
# Out:
# (6779, 37)

# %%
nhanes=df['Education'].value_counts()
print(nhanes)
# Out:
# Education
# Some College      1423
# College Grad      1246
# High School        993
# 9 - 11th Grade     624
# 8th Grade          359
# Name: count, dtype: int64

# %%
freq_table=pd.crosstab(df['Education'],'count')
freq_table
# Out:
# col_0           count
# Education
# 8th Grade         359
# 9 - 11th Grade    624
# College Grad     1246
# High School       993
# Some College     1423

# %%
freq_table=pd.crosstab(df['Gender'],'Ann')
freq_table
# Out:
# col_0    Ann
# Gender
# female  3420
# male    3359

# %%
freq_table=pd.crosstab(df['Gender'],'Frequency')
freq_table
# Out:
# col_0   Frequency
# Gender
# female       3420
# male         3359

# %%
freq_table=pd.crosstab(df['Education'],df['HHIncome'])
freq_table
# Out:
# HHIncome        0-4999  10000-14999  15000-19999  20000-24999  25000-34999  \
# Education
# 8th Grade           15           35           46           45           55
# 9 - 11th Grade      26           64           57           61           77
# College Grad        13           14           31           25           66
# High School         21           95           74           80          119
# Some College        23           90           70           86          149
#
# HHIncome        35000-44999  45000-54999  5000-9999  55000-64999  65000-74999  \
# Education
# 8th Grade                32           17         23           12            8
# 9 - 11th Grade           56           46         34           32           25
# College Grad             85           80          8           75           81
# High School             114           86         35           62           46
# Some College            136          128         33           92           85
#
# ...

# %%
#normalize by index(rows)
freq_table_normalize= pd.crosstab(df['Education'],'Percentage',normalize=True)
freq_table_normalize
# Out:
# col_0           Percentage
# Education
# 8th Grade         0.077287
# 9 - 11th Grade    0.134338
# College Grad      0.268245
# High School       0.213778
# Some College      0.306351

# %%
Education_counts=df['Education'].value_counts()
Education_counts
# Out:
# Education
# Some College      1423
# College Grad      1246
# High School        993
# 9 - 11th Grade     624
# 8th Grade          359
# Name: count, dtype: int64

# %%
#pie chart for Education
plt.figure(figsize=(8,8))
plt.pie(Education_counts,labels=Education_counts.index,autopct='%1.1f%%',startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x787ea0113c10>,
# ...
#  [Text(-1.0618037103386706, -0.28735497335357313, 'Some College'),
#   Text(0.526063840973381, -0.9660521907331577, 'College Grad'),
#   Text(0.9942053391502632, 0.4706970826392599, 'High School'),
#   Text(0.03847203693118101, 1.0993270224889253, '9 - 11th Grade'),
#   Text(-0.6479339732914001, 0.8889215748618207, '8th Grade')],
#  [Text(-0.5791656601847294, -0.15673907637467624, '30.6%'),
#   Text(0.2869439132582078, -0.5269375585817223, '26.8%'),
#   Text(0.542293821354689, 0.2567438632577781, '21.4%'),
#   Text(0.02098474741700782, 0.5996329213575955, '13.4%'),
#   Text(-0.3534185308862182, 0.484866313560993, '7.7%')])
